# %%
# Out:
# [0, 1, 2, 3, 4, 5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 2
#       1 justtwo_np = students[["sleep","coffee"]].to_numpy()
# ----> 2 my_kmeans(justtwo_np, 6, 2019)
#
# File ~/coding_projects/CSC294-Fall2022/portfolio/portfolio-martasapizhak/code_els/homework-2-martasapizhak/hw2.py:29, in my_kmeans(arr, clusters_num, random_n)
#      27     for i in range(clusters_num):
#      28         inds[i] = labels == i
# ---> 29         clusters[i] = arr[inds[i],:]
#      30         centers[i] = np.mean(clusters[i], axis=0)
#      31 return(centers, labels)
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
gym_coffee = looping_kmeans(gym_coffee, list(range(1,11)))
plt.scatter([i for i in range(1,11)], gym_coffee, c='brown')

# %% [markdown]
# Closest to the elbow - 4
# Which means that given a dataset of gym and coffee relationship the students will fall into 4  clusters, as the method of elbow determining the best number of clusters showed that 4 clusters is the best choice

# %%
all = looping_kmeans(all, list(range(1,11)))
plt.scatter([i for i in range(1,11)], all, c='green')

# %% [markdown]
# Closest to the elbow - 2
# Which means that given a dataset of all numerical data relationship the students will fall into 2  clusters, as the method of elbow determining the best number of clusters showed that 2 clusters has the best measure of goodness by the within cluster sum of squares

# %%
sleep_gpa = looping_kmeans(sleep_gpa, list(range(1,11)))
plt.scatter([i for i in range(1,11)], sleep_gpa, c='blue')

# %% [markdown]
# Closest to the elbow - 3
# Which means that given a dataset of sleep and gpa relationship the students will fall into 3  clusters, as the method of elbow determining the best number of clusters showed that 3 clusters has the best measure of goodness by the within cluster sum of squares

# %% [markdown]
# Question 3: Limitations of k-means
# If you believe that it can, explain; and if not, offer a counter example.
# - k-means work well with numerical data as it's designed to deal with numpy arrays, that take in only numbers
# - because computing k-means involves finding distance, means between data points, calculating them  on categorical variables such as color values would not make sense
# - similarly, operating on ordinal variables would not work
# - adding to all of the above, I, however, believe that it's possible to wrangle data in a way that will allow assign numbers to categorical data and make it make sense when plotting it in clusters.
